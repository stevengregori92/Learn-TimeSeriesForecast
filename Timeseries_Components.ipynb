# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/Learn-TimeSeriesForecast/blob/main/Timeseries_Components.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install luwiji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 MB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.7 MB/s eta 0:00:00
# ...
#   Created wheel for luwiji: filename=luwiji-1.2.1-py2.py3-none-any.whl size=40366828 sha256=b3119a67b9fef64862c9042b7de025330188ff80a84d3088baae65df6027da71
#   Stored in directory: /root/.cache/pip/wheels/ba/90/9e/943ac5067e9cdc185d8f029a1d13278acd52839118acc06c9a
# ...
#   Created wheel for jcopml: filename=jcopml-1.2.2-py2.py3-none-any.whl size=32177 sha256=1ecba55d23990f8c54a30848cb417e3b4a5bb03905514fac29c402fbb6d57171
#   Stored in directory: /root/.cache/pip/wheels/5e/06/58/749e5f1baf2932285758798a92793d4347888826160b025808
# Successfully built luwiji jcopml
# ...

# %%
# !gdown https://drive.google.com/uc?id=1H9eWWEeT7bcfveH_SXc_ibnb5m-BXC3s
# !unzip /content/datats.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1H9eWWEeT7bcfveH_SXc_ibnb5m-BXC3s
# To: /content/datats.zip
# 100% 16.8k/16.8k [00:00<00:00, 51.1MB/s]
# Archive:  /content/datats.zip
#   inflating: datats/airline.csv
#   inflating: datats/cheese_fred.csv
#   inflating: datats/christmas.csv
#   inflating: datats/daily_min_temp.csv
#   inflating: datats/perrin_freres_champagne.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Additive

# %%
from jcopml.time_series.decomposition import additive_decomposition

# %%
df = pd.read_csv('datats/cheese_fred.csv', index_col = 'date', parse_dates=['date'])
series = df.total_cheese_production
series.plot(figsize=(15,5))
# Out:
# <Axes: xlabel='date'>

# %%
components = additive_decomposition(series, plot=True)

# %% [markdown]
# #Multiplicative

# %%
from jcopml.time_series.decomposition import multiplicative_decomposition

# %%
df = pd.read_csv('datats/airline.csv', index_col = 'Date', parse_dates=['Date'])
series = df.passengers
series.plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
components = multiplicative_decomposition(series, plot=True)

# %% [markdown]
# #Seosanal-Trend decomposition with Loess (STL)

# %%
from jcopml.time_series.decomposition import stl_decomposition

# %%
df = pd.read_csv('datats/airline.csv', index_col='Date', parse_dates=['Date'])
series = df.passengers
series.plot(figsize=(15,3))
# Out:
# <Axes: xlabel='Date'>

# %%
components = stl_decomposition(series, plot=True)
